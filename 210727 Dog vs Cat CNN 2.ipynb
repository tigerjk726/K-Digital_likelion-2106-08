# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import array_to_img
import numpy as np
from tensorflow.keras.models import load_model

model = load_model('./model/10-0.3167-0.8650.hdf5')

model.summary()


cls_index = ['고양이','개']

n = 20

test_num = [[0]*n for _ in range(n)]

for i in range(10): 
    f_name = 'cat.' + str(i+1)
    file_path = './images/dogs-vs-cats/train/cat/'+f_name+'.jpg'
    print(file_path)
    test_num[i] = image.load_img(file_path, target_size = (128,128))
    
for i in range(10,20): 
    f_name = 'dog.' + str(i+9)
    file_path = './images/dogs-vs-cats/train/dog/'+f_name+'.jpg'
    print(file_path)
    test_num[i] = image.load_img(file_path, target_size = (128,128)) 
    
for i in range(20):
    plt.figure()
    plt.imshow(test_num[i])
    
    test_num[i] = image.img_to_array(test_num[i])
    test_num[i] = np.expand_dims(test_num[i], axis=0)
    result = model.predict_classes(test_num[i])
    
    if result == 0:
        strName = "Cat"
    else:
        strName = "Dog"
    plt.xlabel(strName)
    
    if i < 10:
        if result == 0:
            print("고양이 : 예측 = 고양이")
        else:
            print("고양이 : 예측 = 개")
    else:
        if result == 0:
            print("개 : 예측 = 고양이")
        else:
            print("개 : 예측 = 개")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 12,939,329
# Trainable params: 12,939,329
# Non-trainable params: 0
# _________________________________________________________________
# ./images/dogs-vs-cats/train/cat/cat.1.jpg
# ./images/dogs-vs-cats/train/cat/cat.2.jpg
# ./images/dogs-vs-cats/train/cat/cat.3.jpg
# ./images/dogs-vs-cats/train/cat/cat.4.jpg
# ./images/dogs-vs-cats/train/cat/cat.5.jpg
# ./images/dogs-vs-cats/train/cat/cat.6.jpg
# ./images/dogs-vs-cats/train/cat/cat.7.jpg
# ./images/dogs-vs-cats/train/cat/cat.8.jpg
# ./images/dogs-vs-cats/train/cat/cat.9.jpg
# ./images/dogs-vs-cats/train/cat/cat.10.jpg
# ./images/dogs-vs-cats/train/dog/dog.19.jpg
# ./images/dogs-vs-cats/train/dog/dog.20.jpg
# ./images/dogs-vs-cats/train/dog/dog.21.jpg
# ./images/dogs-vs-cats/train/dog/dog.22.jpg
# ./images/dogs-vs-cats/train/dog/dog.23.jpg
# ./images/dogs-vs-cats/train/dog/dog.24.jpg
# ./images/dogs-vs-cats/train/dog/dog.25.jpg
# ./images/dogs-vs-cats/train/dog/dog.26.jpg
# ./images/dogs-vs-cats/train/dog/dog.27.jpg
# ./images/dogs-vs-cats/train/dog/dog.28.jpg
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 고양이
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개

# %% [markdown]
# 74-0.1881-0.9234
#
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 고양이
# 개 : 예측 = 고양이
# 개 : 예측 = 개
# 개 : 예측 = 개

# %% [markdown]
# 10-0.3167-0.8650
#
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 고양이 : 예측 = 고양이
# 고양이 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 고양이
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
# 개 : 예측 = 개
