# %%
# %%writefile C:/Users/tiger/Deeplearning/sample.csv
# c1, c2, c3
# 1,1.11, one
# 2,2.22, two
# 3,3.33, three
# Out:
# Writing C:/Users/tiger/Deeplearning/sample.csv

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('sample.csv')
data
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three

# %%
# %%writefile C:/Users/tiger/Deeplearning/sample2.csv
# c1, c2, c3
# 1,1.11, one
# 2,2.22, two
# 3,3.33, three
# Out:
# Writing C:/Users/tiger/Deeplearning/sample2.csv

# %%
pd.read_csv('sample2.csv', names = ['c1','c2','c3'])
# Out:
#    c1    c2      c3
# 0  c1    c2      c3
# 1   1  1.11     one
# 2   2  2.22     two
# 3   3  3.33   three

# %%
#특정한 열을 행 인덱스로 지정하고 싶을때 index_col을 쓴다. 
pd.read_csv('sample2.csv', index_col='c1')
# Out:
#       c2      c3
# c1
# 1   1.11     one
# 2   2.22     two
# 3   3.33   three

# %%
#확장자가 csv가 아닌경우 구분자 또는 쉼표가 없을때 sep으로 지정한다. 길이가 정해지지않은 공백인 경우 \s+ 라는 정규식 문자열 사용

# %%
# %%writefile C:/Users/tiger/Deeplearning/sample3.txt
# c1 c2 c3 c4
# 0.179181 -1.538472  1.347553  0.43381
# 1.024209  0.087307 -1.281997  0.49265
# 0.417899 -2.002308  0.255245 -1.10515
# Out:
# Overwriting C:/Users/tiger/Deeplearning/sample3.txt

# %%
pd.read_table('sample3.txt', sep='\s+')
# Out:
#          c1        c2        c3       c4
# 0  0.179181 -1.538472  1.347553  0.43381
# 1  1.024209  0.087307 -1.281997  0.49265
# 2  0.417899 -2.002308  0.255245 -1.10515

# %%
# %%writefile C:/Users/tiger/Deeplearning/sample4.csv
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# 누락, 4, 44
# Out:
# Overwriting C:/Users/tiger/Deeplearning/sample4.csv

# %%
pd.read_csv('sample4.csv')
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three
# 3  누락  4.00      44

# %%
df = pd.read_csv('sample4.csv', na_values=['누락'])
df
# Out:
#     c1    c2      c3
# 0  1.0  1.11     one
# 1  2.0  2.22     two
# 2  3.0  3.33   three
# 3  NaN  4.00      44

# %%
df.to_csv('sample6.csv')

# %%
# !type C:\Users\tiger\Deeplearning\sample6.csv
# Out:
# ,c1, c2, c3
# 0,1.0,1.11, one
# 1,2.0,2.22, two
# 2,3.0,3.33, three
# 3,,4.0, 44

# %%
pd.read_csv('sample6.csv')
# Out:
#    Unnamed: 0   c1    c2      c3
# 0           0  1.0  1.11     one
# 1           1  2.0  2.22     two
# 2           2  3.0  3.33   three
# 3           3  NaN  4.00      44

# %%
df.to_csv('sample7.txt', sep='|')

# %%
# !type C:\Users\tiger\Deeplearning\sample7.txt
# Out:
# |c1| c2| c3
# 0|1.0|1.11| one
# 1|2.0|2.22| two
# 2|3.0|3.33| three
# 3||4.0| 44

# %%
df.to_csv('sample8.csv', na_rep='missing')

# %%
# !type C:\Users\tiger\Deeplearning\sample8.csv
# Out:
# ,c1, c2, c3
# 0,1.0,1.11, one
# 1,2.0,2.22, two
# 2,3.0,3.33, three
# 3,missing,4.0, 44

# %%
df.index = ['a','b','c','d']
df
# Out:
#     c1    c2      c3
# a  1.0  1.11     one
# b  2.0  2.22     two
# c  3.0  3.33   three
# d  NaN  4.00      44

# %%
df.to_csv('sample9.csv', index=False, header=False)

# %%
# !type C:\Users\tiger\Deeplearning\sample9.csv
# Out:
# 1.0,1.11, one
# 2.0,2.22, two
# 3.0,3.33, three
# ,4.0, 44

# %%
df_titanic = pd.read_csv("https://raw.githubusercontent.com/datascienceschool/docker_rpython/master/data/titanic.csv")

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.to_csv("titanic.csv")

# %%
pd.read_csv('titanic.csv')
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
